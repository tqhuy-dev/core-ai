# %%
import os, getpass
from agentic_doc.parse import parse_documents
# Out:
# 2025-05-28 02:13:06 [info   ] Settings loaded: {
#   "endpoint_host": "https://api.va.landing.ai",
#   "vision_agent_api_key": "YmpsN[REDACTED]",
#   "batch_size": 4,
#   "max_workers": 5,
#   "max_retries": 100,
#   "max_retry_wait_time": 60,
#   "retry_logging_style": "log_msg",
#   "pdf_to_image_dpi": 96,
#   "split_size": 10
# } [agentic_doc.config] (config.py:84)

# %%
if not os.environ.get("VISION_AGENT_API_KEY"):
    os.environ["VISION_AGENT_API_KEY"] = getpass.getpass("Enter Landing API key: ")

# %%
results = parse_documents(["../resources/BusinessCondensed-3MainStreet.pdf"])
parsed_doc = results[0]
print(parsed_doc.markdown)
# Out:
# 2025-05-28 02:14:32 [info   ] Parsing 1 documents            [agentic_doc.parse] (parse.py:54)
# Parsing documents:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-05-28 02:14:32 [info   ] Splitting PDF: '../resources/BusinessCondensed-3MainStreet.pdf' into 0 parts under '/var/folders/dk/8plcwpv53gg0_dg9fkx_rgr00000gn/T/tmpsqezzf0s' [agentic_doc.utils] (utils.py:198)
# 2025-05-28 02:14:32 [info   ] Created /var/folders/dk/8plcwpv53gg0_dg9fkx_rgr00000gn/T/tmpsqezzf0s/BusinessCondensed-3MainStreet_1.pdf [agentic_doc.utils] (utils.py:214)
# 2025-05-28 02:14:32 [info   ] Start parsing document part: 'File name: BusinessCondensed-3MainStreet_1.pdf	Page: [0:3]' [agentic_doc.parse] (parse.py:288)
# Parsing document parts from 'BusinessCondensed-3MainStreet.pdf':   0%|          | 0/1 [00:00<?, ?it/s]
# HTTP Request: POST https://api.va.landing.ai/v1/tools/agentic-document-analysis "HTTP/1.1 200 OK" (_client.py:1025)
# ...

# %%
with open('../resources/parsed_doc.markdown', 'w') as f:
    f.write(parsed_doc.markdown)
